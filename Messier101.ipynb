# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
cs_df=pd.read_csv("Messier 101.csv") #obtained from Gaia

# %%
cs_df
# Out:
#              source_id          ra        dec  parallax  parallax_error  \
# 0  1609275081320934016  210.802183  54.347855       NaN             NaN
# 1  1609275081320938752  210.803471  54.347703  1.250620        0.263620
# 2  1609275081320939136  210.802081  54.348260 -1.000240        0.220147
# 3  1609275081322912000  210.802621  54.349091       NaN             NaN
# 4  1609275081322912256  210.802216  54.348922  1.856779        0.678961
#
#    phot_g_mean_mag     bp_rp  dr2_radial_velocity  dr2_radial_velocity_error
# 0        21.090446       NaN                  NaN                        NaN
# 1        18.913622  0.718439                  NaN                        NaN
# 2        18.505096  0.889332                  NaN                        NaN
# 3        19.351364       NaN                  NaN                        NaN
# 4        18.395683  1.025353                  NaN                        NaN

# %%
sns.jointplot(x="ra", y="dec",data=cs_df, kind="kde")

# %%
data = pd.read_csv("Messier 101.csv")
y=data["dec"]
x=data['ra']
res = sns.kdeplot(x,y,color='blue',shade=True)
plt.xlabel("RA")
plt.ylabel("DEC")
plt.title("Messier 101")
plt.show()
# Out:
# /Users/kiarajacob/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
