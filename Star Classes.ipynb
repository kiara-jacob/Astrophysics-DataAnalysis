# %% [markdown]
# USING DATA OF VARIOUS STAR CLASSES TO OBTAIN SCATTERPLOTS AND BOXPLOTS
# data source: https://www.kaggle.com/deepu1109/star-dataset?select=6+class+csv.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
cs_df=pd.read_csv("StarClasses.csv")

# %%
cs_df
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0               3068          0.002400        0.1700                   16.12
# 1               3042          0.000500        0.1542                   16.60
# 2               2600          0.000300        0.1020                   18.70
# 3               2800          0.000200        0.1600                   16.65
# 4               1939          0.000138        0.1030                   20.06
# ..               ...               ...           ...                     ...
# 235            38940     374830.000000     1356.0000                   -9.93
# 236            30839     834042.000000     1194.0000                  -10.63
# 237             8829     537493.000000     1423.0000                  -10.73
# 238             9235     404940.000000     1112.0000                  -11.23
# 239            37882     294903.000000     1783.0000                   -7.80
#
#      Star type Star color Spectral Class
# ...

# %%
cs_df_subset = cs_df[['Temperature (K)', 'Luminosity(L/Lo)','Star type' ]]
cs_df['Star type'] = cs_df['Star type'].astype(int)
cs_df_subset  #SUBSET OF THE MAIN DATA FRAME
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Star type
# 0               3068          0.002400          0
# 1               3042          0.000500          0
# 2               2600          0.000300          0
# 3               2800          0.000200          0
# 4               1939          0.000138          0
# ..               ...               ...        ...
# 235            38940     374830.000000          5
# 236            30839     834042.000000          5
# 237             8829     537493.000000          5
# 238             9235     404940.000000          5
# 239            37882     294903.000000          5
#
# [240 rows x 3 columns]

# %%
dwarf_df= new.loc[0:29,['Temperature (K)', 'Luminosity(L/Lo)','Star type']] #BROWN, RED  & WHITE DWARF
dwarf_df
# Out:
#     Temperature (K)  Luminosity(L/Lo)  Star type
# 0              3068          0.002400          0
# 1              3042          0.000500          0
# 2              2600          0.000300          0
# 3              2800          0.000200          0
# 4              1939          0.000138          0
# 5              2840          0.000650          0
# 6              2637          0.000730          0
# 7              2600          0.000400          0
# 8              2650          0.000690          0
# 9              2700          0.000180          0
# 10             3600          0.002900          1
# 11             3129          0.012200          1
# 12             3134          0.000400          1
# 13             3628          0.005500          1
# 14             2650          0.000600          1
# 15             3340          0.003800          1
# 16             2799          0.001800          1
# 17             3692          0.003670          1
# ...

# %%
giants_df= cs_df_subset.loc[220: ,['Temperature (K)', 'Luminosity(L/Lo)','Star type']] #Supergiants and Hypergiants
giants_df
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Star type
# 220            23678          244290.0          4
# 221            12749          332520.0          4
# 222             9383          342940.0          4
# 223            23440          537430.0          4
# 224            16787          246730.0          4
# 225            18734          224780.0          4
# 226             9892          593900.0          4
# 227            10930          783930.0          4
# 228            23095          347820.0          4
# 229            21738          748890.0          4
# 230            24145          382993.0          5
# 231            38234          272830.0          5
# 232            32489          648430.0          5
# 233            27739          849420.0          5
# 234            21904          748490.0          5
# 235            38940          374830.0          5
# 236            30839          834042.0          5
# 237             8829          537493.0          5
# ...

# %%
a=dwarf_df["Temperature (K)"]
b=dwarf_df["Luminosity(L/Lo)"]

plt.scatter(a,b, c='coral',s=100)


x=giants_df["Temperature (K)"]
y=giants_df["Luminosity(L/Lo)"]

plt.scatter(x,y,c='lightblue',s=100)



plt.title("Temperature vs Luminosity Dwarf Stars and Giant Stars")

plt.xlabel("Temperature (K)")
plt.ylabel("Luminosity (L/Lo)")
plt.legend(["Dwarf Stars","Giant Stars"], loc ="best")

# %%
mag = cs_df[['Absolute magnitude(Mv)','Star type' ]]

mag.boxplot(by="Star type", patch_artist=True,figsize=(7,7))
plt.xlabel("STAR TYPES")
# Out:
# Text(0.5, 0, 'STAR TYPES')

# %%
sns.pairplot(cs_df)
